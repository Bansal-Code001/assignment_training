# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = pd.read_csv("tips.csv")
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
#url = "https://raw.githubusercontent.com/mwaskom/seaborn-data/master/tips.csv"
df = pd.read_csv("tips.csv")

# %%
sns.lineplot(df["total_bill"])
# Out:
# <Axes: ylabel='total_bill'>

# %%
sns.scatterplot(x = df["total_bill"], y = df["tip"],data = df, marker="2")
plt.title("graph",fontsize=20,
          color="grey",
          fontweight="bold",
          backgroundcolor="black",
          style ="italic")
# Out:
# Text(0.5, 1.0, 'graph')

# %%
sns.histplot(df["total_bill"])
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
sns.barplot(df["total_bill"])
# Out:
# <Axes: ylabel='total_bill'>

# %%
sns.barplot(x = "day", y="total_bill", data=df)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.kdeplot(df["total_bill"])
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %% [markdown]
# ### sns
# - catagorical plot -- catplot
# - relationship plot -- relplot

# %%
sns.relplot(x = df["total_bill"],y=df["tip"])

# %%
sns.catplot(x = "day", y="total_bill", data = df,hue="smoker",kind="box")

# %%
sns.boxplot(df["total_bill"])
# Out:
# <Axes: ylabel='total_bill'>

# %%
## outliners -- remove ya transform 
q1  = df["total_bill"].quantile(0.25)
q3  = df["total_bill"].quantile(0.75)
iqr = q3-q1

lower_bound = q1 - 1.5*iqr
upper_bound = q3 - 1.5*iqr
df[df["total_bill"]>upper_bound]
df[df["total_bill"]<lower_bound]
df = df[(df["total_bill"]>lower_bound)&(df["total_bill"]<upper_bound)]
sns.boxplot(df["total_bill"])
# Out:
# <Axes: ylabel='total_bill'>

# %%
sns.displot(df["total_bill"],kde=True)

# %%
sns.jointplot(x="total_bill",y = "tip",data=df,kind="hex")

# %%
sns.pairplot(df)

# %%
sns.relplot(x="total_bill", y="tip", data=df, kind="scatter", hue="time", style="size")

# %%
sns.relplot(x="total_bill", y="tip", data=df, kind="scatter", hue="time", style="size",col="day")
